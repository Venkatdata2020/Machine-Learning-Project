# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('Customer-Churn.csv')
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ...  DeviceProtection  \
# 0  No phone service             DSL             No  ...                No
# 1                No             DSL            Yes  ...               Yes
# 2                No             DSL            Yes  ...                No
# 3  No phone service             DSL            Yes  ...               Yes
# 4                No     Fiber optic             No  ...                No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges Churn
# 0           Electronic check          29.85         29.85    No
# 1               Mailed check          56.95        1889.5    No
# 2               Mailed check          53.85        108.15   Yes
# 3  Bank transfer (automatic)          42.30       1840.75    No
# 4           Electronic check          70.70        151.65   Yes
#
# [5 rows x 21 columns]

# %%
Customer_5 = data.iloc[:,4]
Customer_5.sample(2)
# Out:
# 3939    Yes
# 2612    Yes
# Name: Dependents, dtype: object

# %%
c = data.loc[:,['Dependents','tenure']]

# %%
c.sample(2)
# Out:
#      Dependents  tenure
# 3280         No      55
# 3507         No       4

# %%
Senoir_male_electronic = data[(data['gender'] == 'Male') & (data['SeniorCitizen'] == 1) & (data['PaymentMethod']=='Electronic check ')]
Senoir_male_electronic.shape
# Out:
# (0, 21)

# %%
customer_total_tenure = data[(data['tenure']>70) | (data['MonthlyCharges'] > 100)]
customer_total_tenure
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 8     7892-POOKP  Female              0     Yes         No      28
# 12    8091-TTVAX    Male              0     Yes         No      58
# 13    0280-XJGEX    Male              0      No         No      49
# 14    5129-JLPIS    Male              0      No         No      25
# 15    3655-SNQYZ  Female              0     Yes        Yes      69
# 17    9959-WOFKT    Male              0      No        Yes      71
# 28    5248-YGIJN    Male              0     Yes         No      72
# 30    3841-NFECX  Female              1     Yes         No      71
# 35    6234-RAAPL  Female              0     Yes        Yes      72
# 38    5380-WJKOV    Male              0      No         No      34
# 57    5067-XJQFU    Male              1     Yes        Yes      66
# 59    5954-BDFSG  Female              0      No         No      72
# 60    0434-CSFON  Female              0     Yes         No      47
# 62    0526-SXDJP    Male              0     Yes         No      72
# 72    1891-QRQSA    Male              1     Yes        Yes      64
# 75    2673-CXQEU  Female              1      No         No      56
# 83    9919-YLNNG  Female              0      No         No      42
# 93    6067-NGCEU  Female              0      No         No      65
# 94    9848-JQJTX    Male              0      No         No      72
# 96    9803-FTJCG    Male              0     Yes        Yes      71
# 104   3192-NQECA    Male              0     Yes         No      68
# 106   6728-DKUCO  Female              0     Yes        Yes      72
# 109   2848-YXSMW    Male              0     Yes        Yes      72
# 117   5299-RULOA  Female              0     Yes        Yes      10
# 127   6734-PSBAW    Male              0     Yes         No      72
# 129   2639-UGMAZ    Male              1      No         No      71
# 140   3146-MSEGF  Female              1     Yes        Yes      72
# 142   1095-WGNGG  Female              0     Yes         No      61
# 144   1131-QQZEB    Male              1     Yes         No      71
# 152   1679-JRFBR  Female              0     Yes        Yes      70
# ...          ...     ...            ...     ...        ...     ...
# 6886  7234-FECYN  Female              1      No         No       8
# 6894  1400-MMYXY    Male              1     Yes         No       3
# 6898  1956-YIFGE    Male              0     Yes        Yes      22
# 6910  0530-IJVDB    Male              0      No        Yes      70
# 6913  8213-TAZPM  Female              0     Yes        Yes      69
# 6914  7142-HVGBG    Male              1     Yes         No      43
# 6915  1304-SEGFY  Female              0     Yes         No      72
# 6917  2904-GGUAZ  Female              0     Yes         No      72
# 6918  8267-ZNYVZ  Female              0     Yes         No      33
# 6934  6257-DTAYD    Male              0     Yes         No      71
# 6935  4616-ULAOA  Female              0     Yes        Yes      65
# 6940  2314-TNDJQ  Female              0     Yes        Yes      72
# 6947  2898-MRKPI    Male              0     Yes        Yes      68
# 6948  2750-BJLSB  Female              0      No         No      47
# 6952  6394-MFYNG  Female              0      No         No      48
# 6962  0886-QGENL  Female              1     Yes         No      27
# 6963  9547-ITEFG    Male              0     Yes        Yes       9
# 6972  6664-FPDAC  Female              1      No         No      56
# 6982  8468-FZTOE  Female              0     Yes        Yes      72
# 6987  5981-ZVXOT  Female              1      No         No      35
# 6992  0218-QNVAS    Male              0     Yes        Yes      71
# 7002  9586-JGQKH  Female              0     Yes         No      64
# 7006  0093-XWZFY    Male              0      No         No      40
# 7007  2274-XUATA    Male              1     Yes         No      72
# 7022  7203-OYKCT    Male              0      No         No      72
# 7023  1035-IPQPU  Female              1     Yes         No      63
# 7034  0639-TSIQW  Female              0      No         No      67
# 7037  2569-WGERO  Female              0      No         No      72
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  \
# 8             Yes               Yes     Fiber optic                   No
# 12            Yes               Yes     Fiber optic                   No
# 13            Yes               Yes     Fiber optic                   No
# 14            Yes                No     Fiber optic                  Yes
# 15            Yes               Yes     Fiber optic                  Yes
# 17            Yes               Yes     Fiber optic                  Yes
# 28            Yes               Yes             DSL                  Yes
# 30            Yes               Yes     Fiber optic                  Yes
# 35            Yes               Yes     Fiber optic                  Yes
# 38            Yes               Yes     Fiber optic                   No
# 57            Yes               Yes     Fiber optic                   No
# 59            Yes               Yes     Fiber optic                   No
# 60            Yes               Yes     Fiber optic                   No
# 62             No  No phone service             DSL                  Yes
# 72            Yes               Yes     Fiber optic                  Yes
# 75            Yes               Yes     Fiber optic                  Yes
# 83            Yes                No     Fiber optic                   No
# 93            Yes               Yes     Fiber optic                  Yes
# 94            Yes               Yes     Fiber optic                   No
# 96            Yes               Yes             DSL                  Yes
# 104           Yes               Yes     Fiber optic                   No
# 106           Yes               Yes     Fiber optic                  Yes
# 109           Yes                No              No  No internet service
# 117           Yes               Yes     Fiber optic                  Yes
# 127           Yes               Yes              No  No internet service
# 129            No  No phone service             DSL                  Yes
# 140           Yes               Yes             DSL                  Yes
# 142           Yes               Yes     Fiber optic                   No
# 144           Yes               Yes              No  No internet service
# 152           Yes               Yes     Fiber optic                  Yes
# ...           ...               ...             ...                  ...
# 6886          Yes               Yes     Fiber optic                   No
# 6894          Yes               Yes     Fiber optic                   No
# 6898          Yes                No     Fiber optic                   No
# 6910          Yes               Yes     Fiber optic                  Yes
# 6913          Yes               Yes     Fiber optic                   No
# 6914          Yes               Yes     Fiber optic                   No
# 6915          Yes               Yes     Fiber optic                   No
# 6917          Yes               Yes     Fiber optic                  Yes
# 6918          Yes                No     Fiber optic                  Yes
# 6934          Yes               Yes     Fiber optic                   No
# 6935          Yes               Yes     Fiber optic                   No
# 6940           No  No phone service             DSL                  Yes
# 6947          Yes               Yes     Fiber optic                   No
# 6948          Yes                No     Fiber optic                  Yes
# 6952          Yes               Yes     Fiber optic                   No
# 6962          Yes                No     Fiber optic                  Yes
# 6963          Yes               Yes     Fiber optic                   No
# 6972          Yes               Yes     Fiber optic                   No
# 6982          Yes                No             DSL                  Yes
# 6987          Yes               Yes     Fiber optic                  Yes
yes                  Yes                  Yes
#
#           StreamingMovies        Contract PaperlessBilling  \
# 8                     Yes  Month-to-month              Yes
# 12                    Yes        One year               No
# 13                    Yes  Month-to-month              Yes
# 14                    Yes  Month-to-month              Yes
# 15                    Yes        Two year               No
# 17                    Yes        Two year               No
# 28                    Yes        Two year              Yes
# 30                     No        Two year              Yes
# 35                     No        Two year               No
# 38                    Yes  Month-to-month              Yes
# 57                    Yes        One year              Yes
# 59                    Yes        Two year              Yes
# 60                    Yes  Month-to-month              Yes
# 62                     No        Two year               No
# 72                    Yes        Two year              Yes
# 75                    Yes        One year               No
# 83                    Yes  Month-to-month              Yes
# 93                    Yes  Month-to-month              Yes
# 94                    Yes        Two year              Yes
# 96                     No        One year              Yes
# 104                   Yes        Two year              Yes
# 106                   Yes        One year              Yes
# 109   No internet service        Two year               No
# 117                   Yes  Month-to-month              Yes
# 127   No internet service        Two year              Yes
# 129                   Yes        One year              Yes
# 140                   Yes        Two year              Yes
# 142                   Yes        Two year              Yes
# 144   No internet service        Two year               No
# 152                   Yes        One year              Yes
# ...                   ...             ...              ...
# 6886                  Yes  Month-to-month               No
# 6894                  Yes  Month-to-month              Yes
# 6898                  Yes        One year              Yes
# 6910                  Yes        Two year              Yes
# 6913                  Yes        One year              Yes
# 6914                  Yes  Month-to-month              Yes
# 6915                  Yes        Two year              Yes
# 6917                   No        Two year              Yes
# 6918                  Yes        One year              Yes
# 6934                  Yes        Two year              Yes
# 6935                  Yes        Two year              Yes
# 6940                  Yes        Two year               No
# 6947                  Yes        One year              Yes
# 6948                  Yes        One year              Yes
# 6952                  Yes  Month-to-month              Yes
# 6962                  Yes  Month-to-month              Yes
# 6963                  Yes  Month-to-month              Yes
# 6972                  Yes        One year              Yes
# 6982                  Yes        Two year              Yes
# 6987                  Yes        One year              Yes
# 6992                  Yes        One year               No
# 7002                  Yes        Two year              Yes
# 7006                  Yes  Month-to-month              Yes
# 7007                  Yes        Two year              Yes
# 7022                  Yes        One year              Yes
# 7023                  Yes  Month-to-month              Yes
# 7034                   No  Month-to-month              Yes
# 7037  No internet service        Two year              Yes
# 7039                  Yes        One year              Yes
# 7042                  Yes        Two year              Yes
#
#                   PaymentMethod MonthlyCharges  TotalCharges Churn
# 8              Electronic check         104.80       3046.05   Yes
# 12      Credit card (automatic)         100.35        5681.1    No
# 13    Bank transfer (automatic)         103.70        5036.3   Yes
# 14             Electronic check         105.50       2686.05    No
# 15      Credit card (automatic)         113.25       7895.15    No
# 17    Bank transfer (automatic)         106.70       7382.25    No
# 28      Credit card (automatic)          90.25       6369.45    No
# 30      Credit card (automatic)          96.35       6766.95    No
# 35    Bank transfer (automatic)          99.90        7251.7    No
# 38             Electronic check         106.35       3549.25   Yes
# 57             Electronic check         108.45       7076.35    No
# 59      Credit card (automatic)         107.50        7853.7    No
# 60             Electronic check         100.50        4707.1    No
# 62    Bank transfer (automatic)          42.10          2962    No
# 72    Bank transfer (automatic)         111.60          7099    No
# 75             Electronic check         110.50        6139.5    No
# 83    Bank transfer (automatic)         103.80        4327.5    No
# 93      Credit card (automatic)         111.05          7107    No
# 94    Bank transfer (automatic)         100.90       7459.05    No
# 96      Credit card (automatic)          66.85        4748.7    No
# 104   Bank transfer (automatic)         110.00       7611.85   Yes
# 106            Electronic check         104.15       7303.05    No
# 109     Credit card (automatic)          19.40       1363.25    No
# 117            Electronic check         100.25       1064.65   Yes
# 127   Bank transfer (automatic)          23.55       1723.95    No
# 129            Electronic check          56.45       3985.35    No
# 140     Credit card (automatic)          88.05       6425.65    No
# 142   Bank transfer (automatic)         101.05       5971.25    No
# 144   Bank transfer (automatic)          23.95        1756.2    No
# 152     Credit card (automatic)         108.15       7930.55    No
# ...                         ...            ...           ...   ...
# 6886           Electronic check         101.35         780.5   Yes
# 6894           Electronic check         105.90        334.65   Yes
# 6898               Mailed check         100.05       2090.25    No
# 6910           Electronic check         114.60        7882.5    No
# 6913  Bank transfer (automatic)         108.75       7493.05    No
# 6914           Electronic check         103.00        4414.3   Yes
# 6915           Electronic check          97.85        6841.3    No
# 6917  Bank transfer (automatic)          84.05       6052.25    No
# 6918           Electronic check         103.75       3361.05   Yes
# 6934    Credit card (automatic)         104.15        7365.3    No
# 6935    Credit card (automatic)         110.80        7245.9    No
# 6940    Credit card (automatic)          55.65       3880.05    No
# 6947    Credit card (automatic)         101.05        6770.5    No
# 6948           Electronic check         103.70        4730.6    No
# 6952  Bank transfer (automatic)         107.40        5121.3   Yes
# 6962           Electronic check         101.25       2754.45   Yes
# 6963    Credit card (automatic)         102.60        897.75    No
# 6972           Electronic check         111.95        6418.9   Yes
# 6982           Electronic check          74.35        5237.4    No
# 6987           Electronic check         108.35       3726.15    No
# 6992  Bank transfer (automatic)         100.55       7113.75    No
# 7002  Bank transfer (automatic)         105.40       6794.75    No
# 7006    Credit card (automatic)         104.50       4036.85   Yes
# 7007  Bank transfer (automatic)          63.10       4685.55    No
# 7022           Electronic check         104.95        7544.3    No
# 7023           Electronic check         103.50        6479.4    No
# 7034    Credit card (automatic)         102.95       6886.25   Yes
# 7037  Bank transfer (automatic)          21.15        1419.4    No
# 7039    Credit card (automatic)         103.20        7362.9    No
# 7042  Bank transfer (automatic)         105.65        6844.5    No
#
# [1259 rows x 21 columns]

# %%
two_mail_yes = data[(data['Contract'] == 'Two year') & (data['PaymentMethod'] == 'Mailed check') & (data['Churn'] == 'Yes')]
two_mail_yes
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 268   6323-AYBRX    Male              0      No         No      59
# 5947  7951-QKZPL  Female              0     Yes        Yes      33
# 6680  9412-ARGBX  Female              0      No        Yes      48
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...   \
# 268           Yes            No              No  No internet service  ...
# 5947          Yes           Yes              No  No internet service  ...
# 6680          Yes            No     Fiber optic                   No  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 268   No internet service  No internet service  No internet service
# 5947  No internet service  No internet service  No internet service
# 6680                  Yes                  Yes                  Yes
#
#           StreamingMovies  Contract PaperlessBilling PaymentMethod  \
# 268   No internet service  Two year               No  Mailed check
# 5947  No internet service  Two year              Yes  Mailed check
# 6680                   No  Two year              Yes  Mailed check
#
#      MonthlyCharges  TotalCharges Churn
# 268           19.35        1099.6   Yes
# 5947          24.50         740.3   Yes
# 6680          95.50       4627.85   Yes
#
# [3 rows x 21 columns]

# %%
customer_333 = data.sample(n=333)
customer_333
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
#
# 6758  ...   No internet service  No internet service  No internet service
# 2840  ...                    No                  Yes                   No
# 1620  ...                    No                  Yes                   No
# 5677  ...                   Yes                   No                   No
# 5759  ...                    No                   No                   No
# 1032  ...                   Yes                   No                  Yes
# 7005  ...   No internet service  No internet service  No internet service
# 2275  ...                    No                   No                   No
# 6466  ...                    No                   No                   No
# 3965  ...                   Yes                   No                  Yes
# 6510  ...                   Yes                  Yes                   No
# 4388  ...   No internet service  No internet service  No internet service
# 6764  ...                    No                   No                   No
# 5948  ...                    No                  Yes                   No
# 4458  ...                   Yes                   No                  Yes
# 388   ...                   Yes                   No                   No
# ...   ...                   ...                  ...                  ...
# 1398  ...                    No                  Yes                   No
# 4395  ...                   Yes                   No                  Yes
# 3348  ...                   Yes                   No                  Yes
# 265   ...                   Yes                  Yes                  Yes
# 5079  ...                    No                  Yes                   No
# 550   ...                   Yes                   No                  Yes
# 4789  ...                    No                   No                   No
# 543   ...                    No                   No                  Yes
# 2444  ...                    No                   No                  Yes
# 6695  ...                   Yes                  Yes                   No
# 6283  ...                   Yes                   No                  Yes
# 7022  ...                   Yes                   No                  Yes
# 1271  ...                   Yes                  Yes                  Yes
# 387   ...                   Yes                  Yes                   No
# 4607  ...                    No                  Yes                   No
# 1661  ...                   Yes                   No                  Yes
# 6149  ...                    No                   No                   No
# 5466  ...   No internet service  No internet service  No internet service
# 5222  ...                   Yes                   No                   No
# 3175  ...                    No                   No                   No
# 2747  ...   No internet service  No internet service  No internet service
# 2007  ...                    No                   No                   No
# 1763  ...                    No                   No                   No
# 5671  ...   No internet service  No internet service  No internet service
# 5825  ...                    No                   No                   No
# 5146  ...                    No                   No                   No
# 3050  ...                    No                  Yes                   No
# 4746  ...                    No                   No                   No
# 2339  ...                    No                   No                  Yes
# 1679  ...                    No                   No                   No
#
#           StreamingMovies        Contract PaperlessBilling  \
# 3379  No internet service  Month-to-month               No
# 6135                  Yes        Two year              Yes
# 1673                  Yes  Month-to-month              Yes
# 2422                   No  Month-to-month              Yes
# 6339                   No  Month-to-month              Yes
# 968                    No        Two year               No
# 5697                  Yes        One year              Yes
# 741                    No  Month-to-month              Yes
# 2785                  Yes        Two year               No
# 6182                  Yes        Two year               No
# 4897                   No  Month-to-month              Yes
# 6800                  Yes        One year               No
# 4783                   No        One year               No
# 2877                  Yes  Month-to-month              Yes
# 6758  No internet service  Month-to-month              Yes
# 2840                   No  Month-to-month               No
# 1620                   No  Month-to-month               No
# 5677                   No        One year               No
# 5759                   No  Month-to-month              Yes
# 1032                  Yes  Month-to-month              Yes
# 7005  No internet service        One year               No
# 2275                   No  Month-to-month              Yes
# 6466                   No  Month-to-month               No
# 3965                  Yes        One year              Yes
# 6510                  Yes        Two year               No
# 4388  No internet service        Two year               No
# 6764                   No  Month-to-month              Yes
# 5948                   No        Two year               No
# 4458                   No  Month-to-month              Yes
# 388                   Yes  Month-to-month              Yes
# ...                   ...             ...              ...
# 1398                   No  Month-to-month              Yes
# 4395                  Yes  Month-to-month              Yes
# 3348                  Yes        One year              Yes
# 265                   Yes        Two year               No
# 5079                  Yes  Month-to-month               No
# 550                   Yes        Two year              Yes
# 4789                   No  Month-to-month               No
# 543                    No  Month-to-month              Yes
# 2444                  Yes  Month-to-month              Yes
# 6695                   No        Two year               No
# 6283                  Yes  Month-to-month              Yes
# 7022                  Yes        One year              Yes
# 1271                   No        One year              Yes
# 387                   Yes        One year              Yes
# 4607                  Yes  Month-to-month              Yes
# 1661                  Yes  Month-to-month              Yes
# 6149                   No        One year               No
# 5466  No internet service        One year              Yes
# 5222                   No  Month-to-month              Yes
# 3175                  Yes  Month-to-month               No
# 2747  No internet service  Month-to-month              Yes
# 2007                  Yes  Month-to-month              Yes
# 1763                   No  Month-to-month              Yes
# 5671  No internet service        Two year               No
# 5825                   No  Month-to-month              Yes
# 5146                  Yes  Month-to-month               No
# 3050                  Yes  Month-to-month              Yes
# 4746                   No  Month-to-month              Yes
# 2339                  Yes  Month-to-month              Yes
# 1679                   No  Month-to-month              Yes
#
#                   PaymentMethod MonthlyCharges  TotalCharges Churn
# 3379               Mailed check          19.30          44.4    No
# 6135  Bank transfer (automatic)         114.00        8175.9    No
# 1673  Bank transfer (automatic)         113.60       4594.95   Yes
# 2422           Electronic check          70.05         70.05    No
# 6339               Mailed check          49.90          49.9   Yes
# 968     Credit card (automatic)          77.35        5550.1    No
# 5697           Electronic check         109.50       7674.55   Yes
# 741            Electronic check          80.45         137.1    No
# 2785           Electronic check         108.90       2809.05    No
# 6182    Credit card (automatic)          88.70       6501.35    No
# 4897  Bank transfer (automatic)          30.20        469.65    No
# 6800               Mailed check         105.95        1348.9   Yes
# 4783           Electronic check          69.20        4982.5    No
# 2877           Electronic check          99.15       6010.05   Yes
# 6758    Credit card (automatic)          19.40        460.25    No
# 2840               Mailed check          84.40       1936.85    No
# 1620  Bank transfer (automatic)          29.05         44.75    No
# 5677           Electronic check          80.80       3132.75    No
# 5759               Mailed check          70.15         70.15   Yes
# 1032           Electronic check          92.10        729.95   Yes
# 7005    Credit card (automatic)          19.30         486.2    No
# 2275           Electronic check          74.50          74.5   Yes
# 6466               Mailed check          74.15          1387    No
# 3965           Electronic check         106.50       5621.85    No
# 6510               Mailed check          99.65        4630.2    No
# 4388               Mailed check          19.40        358.05    No
# 6764           Electronic check          69.20          69.2   Yes
# 5948  Bank transfer (automatic)          84.60        5706.2    No
# 4458           Electronic check          94.65        3624.3   Yes
# 388                Mailed check          90.40          4063    No
# ...                         ...            ...           ...   ...
# 1398           Electronic check          84.35       1938.05    No
# 4395           Electronic check         103.95        7446.9   Yes
# 3348           Electronic check         105.90       7521.95    No
# 265                Mailed check          88.10       5526.75    No
# 5079           Electronic check          95.70        1451.1    No
# 550   Bank transfer (automatic)         110.30        7966.9    No
# 4789               Mailed check          71.10          71.1   Yes
# 543   Bank transfer (automatic)          86.05         834.1   Yes
# 2444           Electronic check          99.95       3186.65   Yes
# 6695               Mailed check          71.10       5224.95    No
# 6283    Credit card (automatic)          99.00         287.4   Yes
# 7022           Electronic check         104.95        7544.3    No
# 1271           Electronic check          53.60        2879.2    No
# 387            Electronic check          54.75       2348.45    No
# 4607               Mailed check          59.55         59.55    No
# 1661  Bank transfer (automatic)         108.80       7082.45    No
# 6149               Mailed check          25.85         25.85    No
# 5466  Bank transfer (automatic)          19.95         219.5    No
# 5222  Bank transfer (automatic)          65.50        573.15    No
# 3175  Bank transfer (automatic)          81.50        1329.2   Yes
# 2747               Mailed check          19.40        168.65    No
# 2007           Electronic check          80.20         181.1   Yes
# 1763           Electronic check          45.40         80.95    No
# 5671  Bank transfer (automatic)          25.30        1554.9    No
# 5825           Electronic check          70.30          70.3   Yes
# 5146           Electronic check          86.20         893.2    No
# 3050    Credit card (automatic)          85.40         425.9   Yes
# 4746           Electronic check          76.50        162.45   Yes
# 2339           Electronic check          94.25       1973.75   Yes
# 1679               Mailed check          45.75         344.2    No
#
# [333 rows x 21 columns]

# %%
len(customer_333)
# Out:
# 333

# %%
data['Contract'].value_counts()
# Out:
# Month-to-month    3875
# Two year          1695
# One year          1473
# Name: Contract, dtype: int64

# %%
data['Churn'].value_counts()
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %%
data['InternetService'].value_counts()
# Out:
# Fiber optic    3096
# DSL            2421
# No             1526
# Name: InternetService, dtype: int64

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
x= data['InternetService'].value_counts().keys().tolist()
y= data['InternetService'].value_counts().tolist()

# %%
plt.bar(x,y, color='orange')
plt.xlabel('Categories of Internet Service')
plt.ylabel('Count of categories')
plt.title('Distribution of Internet Service')
# Out:
# Text(0.5,1,'Distribution of Internet Service')

# %%
plt.hist(data['tenure'], color='green',bins=30)
plt.title('Distibution of service')
# Out:
# Text(0.5,1,'Distibution of service')

# %%
plt.scatter(x=data['tenure'].head(20),y=data['MonthlyCharges'].head(20),color='brown')
plt.xlabel('Tenure of customer')
plt.ylabel('Monthly charges of customer')
plt.title('Tenure vs Monthly Charges')
plt.show()

# %%
data.boxplot(column='tenure',by=['Contract'],figsize=(10,5))

# %% [markdown]
# # Linear Regression

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
from sklearn.model_selection import  train_test_split

# %%
x= data.loc[:,['tenure']].values
y= data.loc[:,['MonthlyCharges']].values

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.30, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
simpleLinearRegression = LinearRegression()
simpleLinearRegression.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
y_pred = simpleLinearRegression.predict(x_test)

# %%
y_pred
# Out:
# array([[60.95089608],
#        [72.98096699],
#        [59.1903979 ],
#        ...,
#        [75.62171426],
#        [70.63363608],
#        [65.6455579 ]])

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_pred,y_test)

# %%
rmse = np.sqrt(mse)

# %%
rmse
# Out:
# 29.394584027273893

# %% [markdown]
# # Logistic Regression

# %%
x= data.loc[:,['MonthlyCharges']].values
y= data.loc[:,['Churn']].values

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.65, random_state=0)

# %%
from sklearn.linear_model import LogisticRegression
logmodel = LogisticRegression()
logmodel.fit(x_train,y_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
y_pred = logmodel.predict(x_test)

# %%
y_pred
# Out:
# array(['No', 'No', 'No', ..., 'No', 'No', 'No'], dtype=object)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
confusion_matrix(y_pred,y_test),accuracy_score(y_pred,y_test)
# Out:
# (array([[3336, 1242],
#         [   0,    0]], dtype=int64), 0.72870249017038)

# %% [markdown]
# # Decision Tree

# %%
x= data.loc[:,['tenure']].values
y= data.loc[:,['Churn']].values

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.80, random_state=0)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
classifier = DecisionTreeClassifier()
classifier.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
y_pred = classifier.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
confusion_matrix(y_pred,y_test),accuracy_score(y_pred,y_test)
# Out:
# (array([[3782, 1088],
#         [ 330,  435]], dtype=int64), 0.7483584738243123)

# %% [markdown]
# # Random Forest:

# %%
x= data.loc[:,['tenure','MonthlyCharges']].values
y= data.loc[:,['Churn']].values

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.30)

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier()
clf.fit(x_train,y_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   This is separate from the ipykernel package so we can avoid doing imports until
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
y_pred = clf.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
confusion_matrix(y_pred,y_test),accuracy_score(y_pred,y_test)
# Out:
# (array([[1355,  334],
#         [ 208,  216]], dtype=int64), 0.7434926644581165)
